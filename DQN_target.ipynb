# %%
#Dominic Zhao

# %%
# %tensorflow_version 2.x

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import gym
print("ok")
from collections import deque
# Out:
# ok

# %% [markdown]
# Preprocessing the pixel inputs (as specified in the paper). the raw atari frames are 210 to 160 pixels. We down-sample it to 110x84 images and grey scale.

# %%
def grayscale(image):
    # take the mean along rbg values to get one output which is the grayscale, no each pixel has 
    #one value on the gray scale 
    #find a way to store it more efficiently, when its in uint8 we have some problems with fit_batcg
    return np.mean(image,axis=2).astype(np.uint8)

def downsample(image):
    #for each 2 pixel, we take one (getting rid of half the pixels)
    return (image[::2,::2])
def preprocess(image):
    #since we are going to use convolutions, we also want to reshape to add a last dimension (channels)
    #if only one image per stack, we need to expand dims
    return grayscale(downsample(image))

# %% [markdown]
# As explained in the DQN paper, the reward is changed to the sign of the reward (+1, -1 or 0)

# %%
def transform_reward(reward):
    return np.sign(reward)

# %% [markdown]
# We now create the DQN model.

# %%
stack_size = 4 # We stack 4 frames

# Initialize deque with zero-images one array for each image
stacked_frames  =  deque([np.zeros((105,80), dtype=np.int) for i in range(stack_size)], maxlen=4)

def stack_frames(stacked_frames, state, is_new_episode):
    # Preprocess frame
    frame = preprocess(state)
    if is_new_episode:
        # Clear our stacked_frames
        stacked_frames = deque([np.zeros((105,80), dtype=np.int) for i in range(stack_size)], maxlen=4)
        
        # Because we're in a new episode, copy the same frame 4x
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        
        # Stack the frames
        stacked_state = np.stack(stacked_frames, axis=2)
        
    else:
        # Append frame to deque, automatically removes the oldest frame
        stacked_frames.append(frame)

        # Build the stacked state (first dimension specifies different frames)
        stacked_state = np.stack(stacked_frames, axis=2) 
    
    return stacked_state, stacked_frames

# %%
def fit_batch(model,gamma,start_states,actions,rewards,next_states,is_terminal,target_model):
    '''this is one Q learning iteration. 
    To be able to have multiple output (instead of one output per action)
    We will multiply the networks output by a mask, which is the one-hot encoded actions 
    so output will be zero unless it's an action we saw. Much faster to have one output per action.
    params:
    - model : the Q network
    -gamma: discount factor
    -start_states: np array of starting states
    -actions: np array of one-hot encoded actions corresponding to the start-states
    -rewards: np array of rewards corresponding to start-states and actions
    -next_states: np of array of resulting states corresponding to start states
    -is terminal: numpy boolean array of if the resulting state is terminal
    -possible_actions: number of possible actions, to determine for the one hot encoding
    '''
    actions=np.array(actions) #comes in as a tuple
    actions_one_hot=np.array([possible_actions[choice] for choice in actions])
 
    # predict all the Q values for each next state. we want to consider all actions so the mast is ones
    #we use a different target model that is updated every N steps.
    next_Q_values=target_model.predict([next_states,np.ones(actions_one_hot.shape).tolist()])
    actions_one_hot=actions_one_hot.tolist()
    #the model only works if the inputs are lists, weirdly
    
    #all the Q values for all the next_states, at all the possible actions
    # if the resulting state is terminal, the Q value is 0 by definition
    next_Q_values[is_terminal]=0
    #reward+gamma*max of next state Q value
    # in the case, if terminal, Q_value is just r
    #in the paper, Q_values correspond to y, the targets
    Q_values=rewards+gamma*np.max(next_Q_values,axis=1)
   

    # we perform a gradient descent step on (y-Q)^2, Q being the output of our current Q network
    #multiply target by action to only consider the actions we chose, since in the algo the chosen action
    model.fit([start_states,actions_one_hot],actions_one_hot*Q_values[:,None], epochs=1, batch_size=len(start_states),verbose=0)
    
    #Since the input only has a size of len(start_states), this fit function only does one step.

# %%
def atari_model(n_actions):
    # Shape of the input and number of chanels (height ,width ,channels)
    # Since we preprocessed the pixels are divided by 2
    SHAPE=(105,80,4)  #stack of 4 windows
    SHAPE2=(n_actions,)
    #defining 2 inputs for the keras model. Eventually we will have a custom neural net so this won't be need
    # for the inputs we have the image and the one hot actions mask
    frames_inputs=tf.keras.layers.Input(SHAPE,name="frames")
    actions_input=tf.keras.layers.Input(SHAPE2, name="mask")
    #normalize the frames input
    normalized=tf.keras.layers.Lambda(lambda x: x/255.0)(frames_inputs)
    #The first layer is 16 filters, with kernel of size 8x8, with stride of 4, relu
    conv_1=tf.keras.layers.Conv2D(16,8,4,activation="relu")(normalized)
    #32 filters, 4x4 kernel , stride 2 , relu
    conv_2=tf.keras.layers.Conv2D(32,4,2,activation='relu')(conv_1)
    
    #flattening 
    conv_flattened=tf.keras.layers.Flatten()(conv_2)
    hidden=tf.keras.layers.Dense(256,activation='relu')(conv_flattened)
    #one single output for each action
    output=tf.keras.layers.Dense(n_actions)(hidden)
    #multiply by the mask
    filtered_output=tf.keras.layers.multiply([output,actions_input])
  
    model = tf.keras.Model(inputs=[frames_inputs, actions_input], outputs=filtered_output)
    optimizer=tf.keras.optimizers.RMSprop(lr=0.00025, rho=0.95, epsilon=0.01)
    model.compile(optimizer, loss='mse')
    return model

# %%
def q_iteration(env,model,state,iteration,memory,stacked_frames,target_model):
    # Choose epsilon based on the iteration
    # follow the paper to get the epsilon schedule
    epsilon=get_epsilon_for_iteration(iteration)
    #choose the action 
    if np.random.random()<epsilon:
        action=env.action_space.sample()
        #we need to one hot encode
        #action=possible_actions[choice].tolist()
    else:
        action=np.argmax(choose_best_action(model,state))
    new_state,reward,is_done,_=env.step(action)

    #We want the stacked new_state
    new_state, stacked_frames=stack_frames(stacked_frames,new_state,False)


    memory.add(state,action,reward,new_state,is_done)
    # from the memory, sample a batch , and perform one step
    batch=memory.sample_batch(32)
    #sample_batch is of the shape (state, action, rewards,new_state, is_terminal)
    gamma=0.99
    #we can worry about gamma later
    
    #the batch arrives as a list of tuples (state,action,reward,next_state,is_done)
    #we have to unzip
    state_, action_, reward_, next_state_ , is_done_= tuple(zip(*batch))
    fit_batch(model,gamma,state_,action_,reward_,next_state_,is_done_,target_model)
    
    return new_state, reward ,is_done , stacked_frames

# %% [markdown]
# To implement: 1) Memory class , with add function and sample_batch(number), this is the experience replay buffer
# 2)get_epsilon_for_iteration, from the schedule
# 3) choose_best_action (argmax of model(state,action)

# %%
class Memory():
    def __init__(self,max_size):
        self.buffer=deque(maxlen=max_size)
    def add(self,state,action,reward,next_state,is_done):
        self.buffer.append((state,action,reward,next_state,is_done))
    def sample_batch(self,batch_size):
        buffer_size=len(self.buffer)
        index=np.random.choice(np.arange(buffer_size),size=batch_size,replace=False)
        return [self.buffer[i] for i in index]

# %%
def instantiate_memory(max_size, pretrain_length,possible_actions,stacked_frames):
    #pretrain_length is how much we want to populate the memory before hand.
    #max_size is the maximum size of the memory
    memory=Memory(max_size=max_size)
    for i in range(pretrain_length):
        #if it's first step
        if i==0:
            state=env.reset()
            state,stacked_frames=stack_frames(stacked_frames,state,True)
        action=np.random.randint(1,len(possible_actions))-1
        next_state,reward,done,_=env.step(np.argmax(action))
        next_state,stacked_frames=stack_frames(stacked_frames,next_state,False)
        if done:
            next_state=np.zeros(state.shape)
            memory.add(state,action,reward,next_state,done)
            state=env.reset()
            #if done, it means we are dead
            state,stacked_frames=stack_frames(stacked_frames,state,True)
        else:
            memory.add(state,action,reward,next_state,done)
            state=next_state
            #now we can do another loop
    return memory

# %%
def get_epsilon_for_iteration(iteration):
    if iteration<=1000000: 
        return 1-(iteration+1)*0.0000009
    else:
        return 0.1

# %%
def choose_best_action(model,state):
    l=[]
    for i in range(possible_actions.shape[0]):
        l.append(state)
    Q_values=model.predict([l,possible_actions.tolist()])
    choice=np.argmax(np.diagonal(Q_values))
    action=possible_actions[choice].tolist()
    return action

# %% [markdown]
# Let's start training

# %%
env=gym.make("BreakoutDeterministic-v4")
possible_actions=np.array(np.identity(env.action_space.n,dtype=float).tolist())

# %%
#define the hyperparmeters and parameters
total_episodes=50000
max_steps=10000000
#for memory
max_size=1000000
pretrain_length=50000
target_model_update=10000

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
'''
0 = all messages are logged (default behavior)
1 = INFO messages are not printed
2 = INFO and WARNING messages are not printed
3 = INFO, WARNING, and ERROR messages are not printed


'''

tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
my_dqn=atari_model(len(possible_actions))
target_network=atari_model(len(possible_actions))
stacked_frames  =  deque([np.zeros((105,80), dtype=np.int) for i in range(stack_size)], maxlen=4)
memory=instantiate_memory(max_size,pretrain_length,possible_actions,stacked_frames)
iteration=0
for episode in range(total_episodes):
    #set step to 0
    step=0
    #Initialize rewards of the episode
    episode_rewards=[]
    #for new epsiode, we observe the first state
    state=env.reset()
    state,stacked_frames=stack_frames(stacked_frames,state,True)
    while step<max_steps:
        #performs one q iteration and feed the new_state to state for the next q iteration
        new_state, reward, is_done,stacked_frames=q_iteration(env,my_dqn,state,iteration,memory,stacked_frames,target_network)
        state=new_state
        episode_rewards.append(reward)
        step+=1
        iteration+=1
        if iteration%target_model_update==0:
          target_network=tf.keras.models.clone_model(my_dqn)
          target_network.set_weights(my_dqn.get_weights())
          print("target network updated")
        if is_done:
            print("IS DONE--------------------------------------------")
            step=max_steps
        
            #if is_done , the episode is finished
    print("Episode {}".format(episode),
                 "Total reward: {}".format(np.sum(episode_rewards))
                 )
print("done")
# Out:
# IS DONE--------------------------------------------
# Episode 0 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 1 Total reward: 5.0
# IS DONE--------------------------------------------
# Episode 2 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 3 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 4 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 5 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 6 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 7 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 8 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 9 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 10 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 11 Total reward: 5.0
# IS DONE--------------------------------------------
# Episode 12 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 13 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 14 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 15 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 16 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 17 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 18 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 19 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 20 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 21 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 22 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 23 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 24 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 25 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 26 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 27 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 28 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 29 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 30 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 31 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 32 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 33 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 34 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 35 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 36 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 37 Total reward: 5.0
# IS DONE--------------------------------------------
# Episode 38 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 39 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 40 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 41 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 42 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 43 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 44 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 45 Total reward: 5.0
# IS DONE--------------------------------------------
# Episode 46 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 47 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 48 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 49 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 50 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 51 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 52 Total reward: 1.0
# target network updated
# IS DONE--------------------------------------------
# Episode 53 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 54 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 55 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 56 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 57 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 58 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 59 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 60 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 61 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 62 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 63 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 64 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 65 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 66 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 67 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 68 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 69 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 70 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 71 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 72 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 73 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 74 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 75 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 76 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 77 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 78 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 79 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 80 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 81 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 82 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 83 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 84 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 85 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 86 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 87 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 88 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 89 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 90 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 91 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 92 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 93 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 94 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 95 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 96 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 97 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 98 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 99 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 100 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 101 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 102 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 103 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 104 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 105 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 106 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 107 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 108 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 109 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 110 Total reward: 1.0
# target network updated
# IS DONE--------------------------------------------
# Episode 111 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 112 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 113 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 114 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 115 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 116 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 117 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 118 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 119 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 120 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 121 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 122 Total reward: 10.0
# IS DONE--------------------------------------------
# Episode 123 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 124 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 125 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 126 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 127 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 128 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 129 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 130 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 131 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 132 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 133 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 134 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 135 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 136 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 137 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 138 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 139 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 140 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 141 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 142 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 143 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 144 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 145 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 146 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 147 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 148 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 149 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 150 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 151 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 152 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 153 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 154 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 155 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 156 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 157 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 158 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 159 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 160 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 161 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 162 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 163 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 164 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 165 Total reward: 0.0
# target network updated
# IS DONE--------------------------------------------
# Episode 166 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 167 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 168 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 169 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 170 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 171 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 172 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 173 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 174 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 175 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 176 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 177 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 178 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 179 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 180 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 181 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 182 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 183 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 184 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 185 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 186 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 187 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 188 Total reward: 6.0
# IS DONE--------------------------------------------
# Episode 189 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 190 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 191 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 192 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 193 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 194 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 195 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 196 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 197 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 198 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 199 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 200 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 201 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 202 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 203 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 204 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 205 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 206 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 207 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 208 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 209 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 210 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 211 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 212 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 213 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 214 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 215 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 216 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 217 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 218 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 219 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 220 Total reward: 1.0
# target network updated
# IS DONE--------------------------------------------
# Episode 221 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 222 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 223 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 224 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 225 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 226 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 227 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 228 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 229 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 230 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 231 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 232 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 233 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 234 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 235 Total reward: 5.0
# IS DONE--------------------------------------------
# Episode 236 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 237 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 238 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 239 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 240 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 241 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 242 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 243 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 244 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 245 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 246 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 247 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 248 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 249 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 250 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 251 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 252 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 253 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 254 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 255 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 256 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 257 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 258 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 259 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 260 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 261 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 262 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 263 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 264 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 265 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 266 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 267 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 268 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 269 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 270 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 271 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 272 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 273 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 274 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 275 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 276 Total reward: 1.0
# target network updated
# IS DONE--------------------------------------------
# Episode 277 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 278 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 279 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 280 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 281 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 282 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 283 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 284 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 285 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 286 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 287 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 288 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 289 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 290 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 291 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 292 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 293 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 294 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 295 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 296 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 297 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 298 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 299 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 300 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 301 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 302 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 303 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 304 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 305 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 306 Total reward: 5.0
# IS DONE--------------------------------------------
# Episode 307 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 308 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 309 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 310 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 311 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 312 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 313 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 314 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 315 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 316 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 317 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 318 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 319 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 320 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 321 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 322 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 323 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 324 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 325 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 326 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 327 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 328 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 329 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 330 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 331 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 332 Total reward: 3.0
# target network updated
# IS DONE--------------------------------------------
# Episode 333 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 334 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 335 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 336 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 337 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 338 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 339 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 340 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 341 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 342 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 343 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 344 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 345 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 346 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 347 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 348 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 349 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 350 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 351 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 352 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 353 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 354 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 355 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 356 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 357 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 358 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 359 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 360 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 361 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 362 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 363 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 364 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 365 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 366 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 367 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 368 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 369 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 370 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 371 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 372 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 373 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 374 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 375 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 376 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 377 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 378 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 379 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 380 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 381 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 382 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 383 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 384 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 385 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 386 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 387 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 388 Total reward: 1.0
# target network updated
# IS DONE--------------------------------------------
# Episode 389 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 390 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 391 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 392 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 393 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 394 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 395 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 396 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 397 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 398 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 399 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 400 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 401 Total reward: 5.0
# IS DONE--------------------------------------------
# Episode 402 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 403 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 404 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 405 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 406 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 407 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 408 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 409 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 410 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 411 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 412 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 413 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 414 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 415 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 416 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 417 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 418 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 419 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 420 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 421 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 422 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 423 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 424 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 425 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 426 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 427 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 428 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 429 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 430 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 431 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 432 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 433 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 434 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 435 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 436 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 437 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 438 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 439 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 440 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 441 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 442 Total reward: 0.0
# target network updated
# IS DONE--------------------------------------------
# Episode 443 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 444 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 445 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 446 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 447 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 448 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 449 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 450 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 451 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 452 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 453 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 454 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 455 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 456 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 457 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 458 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 459 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 460 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 461 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 462 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 463 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 464 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 465 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 466 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 467 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 468 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 469 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 470 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 471 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 472 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 473 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 474 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 475 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 476 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 477 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 478 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 479 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 480 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 481 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 482 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 483 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 484 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 485 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 486 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 487 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 488 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 489 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 490 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 491 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 492 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 493 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 494 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 495 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 496 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 497 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 498 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 499 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 500 Total reward: 1.0
# target network updated
# IS DONE--------------------------------------------
# Episode 501 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 502 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 503 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 504 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 505 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 506 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 507 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 508 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 509 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 510 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 511 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 512 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 513 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 514 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 515 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 516 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 517 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 518 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 519 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 520 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 521 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 522 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 523 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 524 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 525 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 526 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 527 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 528 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 529 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 530 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 531 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 532 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 533 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 534 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 535 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 536 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 537 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 538 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 539 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 540 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 541 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 542 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 543 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 544 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 545 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 546 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 547 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 548 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 549 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 550 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 551 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 552 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 553 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 554 Total reward: 0.0
# target network updated
# IS DONE--------------------------------------------
# Episode 555 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 556 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 557 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 558 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 559 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 560 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 561 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 562 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 563 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 564 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 565 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 566 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 567 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 568 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 569 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 570 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 571 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 572 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 573 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 574 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 575 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 576 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 577 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 578 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 579 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 580 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 581 Total reward: 0.0
# IS DONE--------------------------------------------
# Episode 582 Total reward: 2.0
# IS DONE--------------------------------------------
# ...
# Episode 3582 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3583 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3584 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3585 Total reward: 5.0
# IS DONE--------------------------------------------
# Episode 3586 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3587 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3588 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3589 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3590 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3591 Total reward: 1.0
# IS DONE--------------------------------------------
# Episode 3592 Total reward: 11.0
# target network updated
# IS DONE--------------------------------------------
# Episode 3593 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3594 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3595 Total reward: 9.0
# IS DONE--------------------------------------------
# Episode 3596 Total reward: 5.0
# IS DONE--------------------------------------------
# Episode 3597 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3598 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3599 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3600 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3601 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3602 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3603 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3604 Total reward: 9.0
# IS DONE--------------------------------------------
# Episode 3605 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3606 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3607 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3608 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3609 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3610 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3611 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3612 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3613 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3614 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3615 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3616 Total reward: 5.0
# IS DONE--------------------------------------------
# Episode 3617 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3618 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3619 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3620 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3621 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3622 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3623 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3624 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3625 Total reward: 8.0
# target network updated
# IS DONE--------------------------------------------
# Episode 3626 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3627 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3628 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3629 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3630 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3631 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3632 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3633 Total reward: 9.0
# IS DONE--------------------------------------------
# Episode 3634 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3635 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3636 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3637 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3638 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3639 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3640 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 3641 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3642 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3643 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3644 Total reward: 9.0
# IS DONE--------------------------------------------
# Episode 3645 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3646 Total reward: 5.0
# IS DONE--------------------------------------------
# Episode 3647 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3648 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3649 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3650 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3651 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3652 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3653 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3654 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3655 Total reward: 10.0
# IS DONE--------------------------------------------
# Episode 3656 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3657 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3658 Total reward: 4.0
# target network updated
# IS DONE--------------------------------------------
# Episode 3659 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3660 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3661 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3662 Total reward: 9.0
# IS DONE--------------------------------------------
# Episode 3663 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 3664 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3665 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3666 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3667 Total reward: 9.0
# IS DONE--------------------------------------------
# Episode 3668 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3669 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3670 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3671 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3672 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3673 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3674 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3675 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3676 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3677 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 3678 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3679 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3680 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3681 Total reward: 5.0
# IS DONE--------------------------------------------
# Episode 3682 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3683 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3684 Total reward: 9.0
# IS DONE--------------------------------------------
# Episode 3685 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3686 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3687 Total reward: 5.0
# IS DONE--------------------------------------------
# Episode 3688 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3689 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3690 Total reward: 11.0
# target network updated
# IS DONE--------------------------------------------
# Episode 3691 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3692 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3693 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3694 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3695 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3696 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3697 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3698 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3699 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 3700 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3701 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3702 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3703 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3704 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3705 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3706 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3707 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3708 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3709 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3710 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3711 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3712 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3713 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3714 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 3715 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3716 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3717 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3718 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3719 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3720 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3721 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3722 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3723 Total reward: 4.0
# target network updated
# IS DONE--------------------------------------------
# Episode 3724 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3725 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3726 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3727 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3728 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3729 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3730 Total reward: 9.0
# IS DONE--------------------------------------------
# Episode 3731 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3732 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3733 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3734 Total reward: 9.0
# IS DONE--------------------------------------------
# Episode 3735 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3736 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3737 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3738 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3739 Total reward: 9.0
# IS DONE--------------------------------------------
# Episode 3740 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3741 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3742 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3743 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3744 Total reward: 4.0
# IS DONE--------------------------------------------
# Episode 3745 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3746 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3747 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3748 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3749 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3750 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3751 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3752 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3753 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3754 Total reward: 3.0
# target network updated
# IS DONE--------------------------------------------
# Episode 3755 Total reward: 5.0
# IS DONE--------------------------------------------
# Episode 3756 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3757 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3758 Total reward: 11.0
# IS DONE--------------------------------------------
# Episode 3759 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3760 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3761 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 3762 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3763 Total reward: 8.0
# IS DONE--------------------------------------------
# Episode 3764 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3765 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3766 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3767 Total reward: 3.0
# IS DONE--------------------------------------------
# Episode 3768 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3769 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3770 Total reward: 7.0
# IS DONE--------------------------------------------
# Episode 3771 Total reward: 2.0
# IS DONE--------------------------------------------
# Episode 3772 Total reward: 3.0

# %%
my_dqn.save('dqn.h5') 
from google.colab import files
files.download('dqn.h5')
